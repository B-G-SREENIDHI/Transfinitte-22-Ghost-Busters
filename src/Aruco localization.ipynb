# %%
import cv2
import sys
import numpy as np

# %%
arucodict = cv2.aruco.Dictionary_get(0)
arucoParams = cv2.aruco.DetectorParameters_create()

coord_dict = {7:np.array([(0,20,0),
                         (20,20,0),
                         (20,0,0),
                         (0,0,0)]),
            6:np.array([(0,20,-90),
                         (20,20,-90),
                         (20,0,-90),
                         (0,0,-90)]),
            10:np.array([(0,20,-180),
                         (20,20,-180),
                         (20,0,-180),
                         (0,0,-180)]),
            0:np.array([(0,20,-270),
                         (20,20,-270),
                         (20,0,-270),
                         (0,0,-270)])}

K = np.array([[900,0,960],
             [0,900,540],
             [0,0,1]]).astype(np.float32)
dist_coeffs = np.zeros((4,1))

# %%
cap = cv2.VideoCapture('t_3-edit.mp4')

pose = [[0],[0],[0]]
rot = [[0],[0],[0]]

while(cap.isOpened()):
  ret, frame = cap.read()
  corners, ids, rejected = cv2.aruco.detectMarkers(frame,arucodict, parameters=arucoParams)
  objp = [0,0,0]
  imgp = [0,0]
  if len(corners) > 0:
    # flatten the ArUco IDs list
    ids = ids.flatten()
    # loop over the detected ArUCo corners
    for (markerCorner, markerID) in zip(corners, ids):
        # extract the marker corners (which are always returned
        # in top-left, top-right, bottom-right, and bottom-left
        # order)
        corners = markerCorner.reshape((4, 2))
        (topLeft, topRight, bottomRight, bottomLeft) = corners
        
        if(topRight[0]-topLeft[0]<0):
            topLeft,bottomRight = bottomRight,topLeft
            topRight,bottomLeft = bottomLeft,topRight
        
        objp = np.vstack([objp,coord_dict[markerID]])
        imgp = np.vstack([imgp,(topLeft, topRight, bottomRight, bottomLeft)])
        print(coord_dict[markerID])
        print((topLeft, topRight, bottomRight, bottomLeft))
        print('________________')
            
        # convert each of the (x, y)-coordinate pairs to integers
        topRight = (int(topRight[0]), int(topRight[1]))
        bottomRight = (int(bottomRight[0]), int(bottomRight[1]))
        bottomLeft = (int(bottomLeft[0]), int(bottomLeft[1]))
        topLeft = (int(topLeft[0]), int(topLeft[1]))
    
        # draw the bounding box of the ArUCo detection
        cv2.line(frame, topLeft, topRight, (0, 255, 0), 2)
        cv2.line(frame, topRight, bottomRight, (255, 0, 0), 2)
        cv2.line(frame, bottomRight, bottomLeft, (0, 0, 255), 2)
        cv2.line(frame, bottomLeft, topLeft, (0, 255, 255), 2)
        # compute and draw the center (x, y)-coordinates of the
        # ArUco marker
        cX = int((topLeft[0] + bottomRight[0]) / 2.0)
        cY = int((topLeft[1] + bottomRight[1]) / 2.0)
        cv2.circle(frame, (cX, cY), 4, (0, 0, 255), -1)
        # draw the ArUco marker ID on the frame
        cv2.putText(frame, str(markerID),
            (topLeft[0], topLeft[1] - 15),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5, (0, 255, 0), 2)
    success, rotation_vector, translation_vector = cv2.solvePnP(objp[1:,:].astype(np.float32), 
                                                                    imgp[1:,:].astype(np.float32),
                                                                    K, dist_coeffs, flags=0)
    pose = np.hstack([pose,translation_vector])
    rot = np.hstack([rot,rotation_vector])
        
    # show the output frame
    cv2.imshow("Frame", frame)
    key = cv2.waitKey(1) & 0xFF
    # if the `q` key was pressed, break from the loop
    if key == ord("q"):
        break
          
# do a bit of cleanup
cv2.destroyAllWindows()

cap.release()
# Out:
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([768., 553.], dtype=float32), array([900., 541.], dtype=float32), array([911., 688.], dtype=float32), array([779., 699.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([573., 547.], dtype=float32), array([759., 531.], dtype=float32), array([773., 721.], dtype=float32), array([588., 735.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([241., 536.], dtype=float32), array([492., 516.], dtype=float32), array([507., 788.], dtype=float32), array([256., 798.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([764., 552.], dtype=float32), array([897., 539.], dtype=float32), array([910., 687.], dtype=float32), array([776., 699.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([571., 544.], dtype=float32), array([756., 528.], dtype=float32), array([770., 722.], dtype=float32), array([585., 733.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([238., 534.], dtype=float32), array([487., 514.], dtype=float32), array([503., 791.], dtype=float32), array([255., 800.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([768., 546.], dtype=float32), array([899., 536.], dtype=float32), array([911., 683.], dtype=float32), array([776., 695.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([577., 544.], dtype=float32), array([752., 529.], dtype=float32), array([767., 711.], dtype=float32), array([589., 725.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([238., 529.], dtype=float32), array([490., 510.], dtype=float32), array([503., 785.], dtype=float32), array([254., 796.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([770., 546.], dtype=float32), array([903., 540.], dtype=float32), array([915., 685.], dtype=float32), array([782., 699.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([574., 543.], dtype=float32), array([761., 526.], dtype=float32), array([775., 718.], dtype=float32), array([589., 729.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([239., 531.], dtype=float32), array([492., 513.], dtype=float32), array([507., 786.], dtype=float32), array([256., 798.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([767., 550.], dtype=float32), array([900., 538.], dtype=float32), array([914., 688.], dtype=float32), array([780., 700.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([572., 543.], dtype=float32), array([759., 527.], dtype=float32), array([773., 722.], dtype=float32), array([588., 733.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([236., 532.], dtype=float32), array([487., 513.], dtype=float32), array([504., 790.], dtype=float32), array([255., 801.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([768., 552.], dtype=float32), array([902., 540.], dtype=float32), array([913., 689.], dtype=float32), array([779., 701.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([572., 544.], dtype=float32), array([759., 529.], dtype=float32), array([774., 722.], dtype=float32), array([587., 735.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([235., 534.], dtype=float32), array([489., 515.], dtype=float32), array([503., 791.], dtype=float32), array([251., 801.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([768., 551.], dtype=float32), array([903., 539.], dtype=float32), array([914., 687.], dtype=float32), array([779., 698.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([572., 543.], dtype=float32), array([758., 527.], dtype=float32), array([774., 721.], dtype=float32), array([586., 733.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([235., 532.], dtype=float32), array([488., 513.], dtype=float32), array([503., 789.], dtype=float32), array([250., 799.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([768., 551.], dtype=float32), array([903., 540.], dtype=float32), array([914., 690.], dtype=float32), array([779., 701.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([571., 544.], dtype=float32), array([759., 529.], dtype=float32), array([774., 723.], dtype=float32), array([586., 736.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([233., 533.], dtype=float32), array([487., 514.], dtype=float32), array([501., 793.], dtype=float32), array([249., 802.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([769., 552.], dtype=float32), array([904., 541.], dtype=float32), array([915., 690.], dtype=float32), array([780., 702.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([571., 544.], dtype=float32), array([759., 529.], dtype=float32), array([775., 723.], dtype=float32), array([585., 736.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([232., 534.], dtype=float32), array([487., 515.], dtype=float32), array([501., 794.], dtype=float32), array([248., 804.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([772., 554.], dtype=float32), array([907., 541.], dtype=float32), array([920., 690.], dtype=float32), array([783., 702.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([575., 545.], dtype=float32), array([763., 530.], dtype=float32), array([778., 724.], dtype=float32), array([589., 737.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([234., 535.], dtype=float32), array([490., 516.], dtype=float32), array([504., 793.], dtype=float32), array([250., 804.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([774., 554.], dtype=float32), array([910., 542.], dtype=float32), array([922., 692.], dtype=float32), array([785., 703.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([576., 546.], dtype=float32), array([765., 530.], dtype=float32), array([780., 726.], dtype=float32), array([592., 739.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([234., 536.], dtype=float32), array([490., 516.], dtype=float32), array([504., 796.], dtype=float32), array([250., 806.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([776., 556.], dtype=float32), array([912., 544.], dtype=float32), array([924., 694.], dtype=float32), array([788., 706.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([578., 548.], dtype=float32), array([767., 532.], dtype=float32), array([782., 728.], dtype=float32), array([593., 741.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([234., 537.], dtype=float32), array([490., 518.], dtype=float32), array([505., 799.], dtype=float32), array([251., 809.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([775., 558.], dtype=float32), array([911., 545.], dtype=float32), array([924., 695.], dtype=float32), array([787., 707.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([576., 550.], dtype=float32), array([766., 534.], dtype=float32), array([781., 730.], dtype=float32), array([591., 743.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([232., 538.], dtype=float32), array([490., 521.], dtype=float32), array([505., 799.], dtype=float32), array([249., 810.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([775., 556.], dtype=float32), array([911., 545.], dtype=float32), array([923., 695.], dtype=float32), array([785., 706.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([575., 549.], dtype=float32), array([764., 533.], dtype=float32), array([780., 729.], dtype=float32), array([590., 742.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([229., 538.], dtype=float32), array([486., 518.], dtype=float32), array([502., 799.], dtype=float32), array([246., 810.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([773., 558.], dtype=float32), array([910., 545.], dtype=float32), array([923., 696.], dtype=float32), array([784., 707.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([573., 548.], dtype=float32), array([764., 534.], dtype=float32), array([780., 729.], dtype=float32), array([589., 742.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([226., 537.], dtype=float32), array([485., 518.], dtype=float32), array([500., 801.], dtype=float32), array([243., 811.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([768., 558.], dtype=float32), array([905., 546.], dtype=float32), array([918., 697.], dtype=float32), array([780., 709.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([567., 551.], dtype=float32), array([758., 534.], dtype=float32), array([774., 732.], dtype=float32), array([582., 744.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([219., 537.], dtype=float32), array([476., 519.], dtype=float32), array([493., 804.], dtype=float32), array([236., 812.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([764., 560.], dtype=float32), array([900., 549.], dtype=float32), array([911., 699.], dtype=float32), array([776., 711.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([560., 551.], dtype=float32), array([751., 536.], dtype=float32), array([767., 733.], dtype=float32), array([581., 745.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([212., 539.], dtype=float32), array([471., 524.], dtype=float32), array([485., 807.], dtype=float32), array([231., 815.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([759., 562.], dtype=float32), array([897., 550.], dtype=float32), array([909., 702.], dtype=float32), array([771., 713.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([558., 555.], dtype=float32), array([748., 538.], dtype=float32), array([765., 735.], dtype=float32), array([573., 747.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([206., 542.], dtype=float32), array([464., 522.], dtype=float32), array([482., 808.], dtype=float32), array([224., 818.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([758., 560.], dtype=float32), array([896., 549.], dtype=float32), array([909., 700.], dtype=float32), array([768., 712.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([556., 552.], dtype=float32), array([748., 537.], dtype=float32), array([763., 735.], dtype=float32), array([570., 747.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([202., 541.], dtype=float32), array([464., 519.], dtype=float32), array([479., 807.], dtype=float32), array([219., 816.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([758., 562.], dtype=float32), array([898., 549.], dtype=float32), array([911., 701.], dtype=float32), array([769., 713.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([557., 553.], dtype=float32), array([750., 537.], dtype=float32), array([765., 736.], dtype=float32), array([572., 748.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([203., 540.], dtype=float32), array([464., 520.], dtype=float32), array([479., 809.], dtype=float32), array([220., 818.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([756., 565.], dtype=float32), array([898., 552.], dtype=float32), array([909., 705.], dtype=float32), array([768., 716.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([555., 555.], dtype=float32), array([748., 539.], dtype=float32), array([764., 739.], dtype=float32), array([570., 751.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([200., 542.], dtype=float32), array([462., 523.], dtype=float32), array([478., 810.], dtype=float32), array([218., 821.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([758., 564.], dtype=float32), array([897., 552.], dtype=float32), array([909., 705.], dtype=float32), array([768., 716.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([555., 556.], dtype=float32), array([749., 539.], dtype=float32), array([763., 740.], dtype=float32), array([571., 753.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([198., 543.], dtype=float32), array([461., 523.], dtype=float32), array([476., 812.], dtype=float32), array([215., 823.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([763., 565.], dtype=float32), array([905., 552.], dtype=float32), array([916., 704.], dtype=float32), array([773., 714.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([561., 554.], dtype=float32), array([754., 538.], dtype=float32), array([769., 738.], dtype=float32), array([576., 752.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([202., 542.], dtype=float32), array([467., 522.], dtype=float32), array([480., 812.], dtype=float32), array([218., 822.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([767., 563.], dtype=float32), array([909., 552.], dtype=float32), array([920., 705.], dtype=float32), array([778., 716.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([564., 554.], dtype=float32), array([759., 539.], dtype=float32), array([773., 739.], dtype=float32), array([579., 752.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([204., 540.], dtype=float32), array([469., 521.], dtype=float32), array([483., 812.], dtype=float32), array([221., 822.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([767., 564.], dtype=float32), array([907., 553.], dtype=float32), array([919., 707.], dtype=float32), array([776., 717.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([562., 556.], dtype=float32), array([756., 540.], dtype=float32), array([773., 741.], dtype=float32), array([578., 753.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([200., 542.], dtype=float32), array([465., 522.], dtype=float32), array([482., 813.], dtype=float32), array([219., 824.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([763., 564.], dtype=float32), array([906., 552.], dtype=float32), array([917., 706.], dtype=float32), array([774., 718.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([560., 555.], dtype=float32), array([755., 539.], dtype=float32), array([769., 742.], dtype=float32), array([575., 754.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([196., 541.], dtype=float32), array([462., 522.], dtype=float32), array([477., 815.], dtype=float32), array([213., 825.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([765., 564.], dtype=float32), array([908., 552.], dtype=float32), array([920., 707.], dtype=float32), array([776., 718.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([561., 555.], dtype=float32), array([756., 538.], dtype=float32), array([771., 741.], dtype=float32), array([576., 754.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([196., 541.], dtype=float32), array([463., 521.], dtype=float32), array([479., 815.], dtype=float32), array([212., 824.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([762., 566.], dtype=float32), array([904., 552.], dtype=float32), array([918., 706.], dtype=float32), array([773., 718.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([557., 556.], dtype=float32), array([752., 538.], dtype=float32), array([769., 742.], dtype=float32), array([574., 755.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([190., 541.], dtype=float32), array([458., 522.], dtype=float32), array([475., 815.], dtype=float32), array([209., 826.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([761., 573.], dtype=float32), array([893., 561.], dtype=float32), array([906., 702.], dtype=float32), array([776., 714.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([547., 554.], dtype=float32), array([744., 541.], dtype=float32), array([763., 743.], dtype=float32), array([551., 752.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([182., 544.], dtype=float32), array([450., 523.], dtype=float32), array([466., 817.], dtype=float32), array([203., 829.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([752., 574.], dtype=float32), array([895., 561.], dtype=float32), array([907., 713.], dtype=float32), array([763., 727.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([546., 565.], dtype=float32), array([743., 547.], dtype=float32), array([757., 751.], dtype=float32), array([556., 761.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([175., 551.], dtype=float32), array([444., 530.], dtype=float32), array([460., 827.], dtype=float32), array([192., 835.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([750., 568.], dtype=float32), array([895., 557.], dtype=float32), array([907., 711.], dtype=float32), array([761., 724.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([544., 559.], dtype=float32), array([740., 542.], dtype=float32), array([755., 750.], dtype=float32), array([560., 760.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([171., 544.], dtype=float32), array([440., 524.], dtype=float32), array([457., 825.], dtype=float32), array([189., 832.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([751., 566.], dtype=float32), array([896., 557.], dtype=float32), array([907., 710.], dtype=float32), array([762., 723.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([546., 560.], dtype=float32), array([743., 543.], dtype=float32), array([755., 749.], dtype=float32), array([559., 759.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([170., 544.], dtype=float32), array([440., 523.], dtype=float32), array([456., 825.], dtype=float32), array([188., 833.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([753., 571.], dtype=float32), array([897., 557.], dtype=float32), array([910., 713.], dtype=float32), array([764., 725.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([547., 560.], dtype=float32), array([744., 544.], dtype=float32), array([759., 750.], dtype=float32), array([562., 762.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([170., 545.], dtype=float32), array([441., 525.], dtype=float32), array([457., 826.], dtype=float32), array([188., 835.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([756., 570.], dtype=float32), array([901., 557.], dtype=float32), array([913., 713.], dtype=float32), array([767., 725.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([548., 560.], dtype=float32), array([747., 543.], dtype=float32), array([761., 749.], dtype=float32), array([564., 761.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([171., 544.], dtype=float32), array([443., 523.], dtype=float32), array([458., 825.], dtype=float32), array([189., 835.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([759., 568.], dtype=float32), array([905., 557.], dtype=float32), array([917., 711.], dtype=float32), array([770., 723.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([552., 559.], dtype=float32), array([750., 542.], dtype=float32), array([765., 748.], dtype=float32), array([566., 760.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([172., 543.], dtype=float32), array([445., 522.], dtype=float32), array([459., 826.], dtype=float32), array([189., 834.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([760., 569.], dtype=float32), array([906., 558.], dtype=float32), array([918., 715.], dtype=float32), array([771., 726.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([552., 560.], dtype=float32), array([751., 544.], dtype=float32), array([766., 751.], dtype=float32), array([568., 763.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([171., 545.], dtype=float32), array([444., 524.], dtype=float32), array([460., 828.], dtype=float32), array([189., 836.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([760., 570.], dtype=float32), array([907., 558.], dtype=float32), array([919., 715.], dtype=float32), array([771., 726.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([552., 560.], dtype=float32), array([751., 543.], dtype=float32), array([766., 751.], dtype=float32), array([567., 763.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([169., 544.], dtype=float32), array([443., 524.], dtype=float32), array([459., 829.], dtype=float32), array([187., 838.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([759., 569.], dtype=float32), array([906., 558.], dtype=float32), array([919., 715.], dtype=float32), array([770., 726.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([550., 560.], dtype=float32), array([751., 544.], dtype=float32), array([766., 751.], dtype=float32), array([565., 763.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([166., 544.], dtype=float32), array([441., 523.], dtype=float32), array([457., 830.], dtype=float32), array([184., 838.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([756., 572.], dtype=float32), array([903., 558.], dtype=float32), array([915., 715.], dtype=float32), array([767., 727.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([545., 561.], dtype=float32), array([746., 543.], dtype=float32), array([761., 751.], dtype=float32), array([563., 763.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([160., 544.], dtype=float32), array([435., 522.], dtype=float32), array([455., 829.], dtype=float32), array([181., 837.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([750., 570.], dtype=float32), array([898., 558.], dtype=float32), array([911., 715.], dtype=float32), array([763., 727.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([541., 560.], dtype=float32), array([741., 543.], dtype=float32), array([757., 751.], dtype=float32), array([556., 763.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([154., 545.], dtype=float32), array([429., 523.], dtype=float32), array([446., 831.], dtype=float32), array([172., 838.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([748., 570.], dtype=float32), array([895., 557.], dtype=float32), array([909., 714.], dtype=float32), array([760., 726.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([536., 559.], dtype=float32), array([738., 542.], dtype=float32), array([755., 752.], dtype=float32), array([554., 764.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([149., 543.], dtype=float32), array([424., 522.], dtype=float32), array([443., 832.], dtype=float32), array([169., 840.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([745., 570.], dtype=float32), array([894., 557.], dtype=float32), array([907., 716.], dtype=float32), array([757., 727.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([535., 559.], dtype=float32), array([736., 542.], dtype=float32), array([752., 755.], dtype=float32), array([551., 765.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([145., 543.], dtype=float32), array([421., 522.], dtype=float32), array([438., 833.], dtype=float32), array([163., 841.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([744., 568.], dtype=float32), array([893., 557.], dtype=float32), array([906., 715.], dtype=float32), array([756., 727.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([534., 560.], dtype=float32), array([735., 542.], dtype=float32), array([750., 755.], dtype=float32), array([548., 764.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([141., 543.], dtype=float32), array([419., 522.], dtype=float32), array([435., 832.], dtype=float32), array([160., 842.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([746., 567.], dtype=float32), array([895., 556.], dtype=float32), array([909., 715.], dtype=float32), array([759., 727.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([535., 559.], dtype=float32), array([736., 541.], dtype=float32), array([752., 753.], dtype=float32), array([550., 764.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([141., 543.], dtype=float32), array([418., 521.], dtype=float32), array([436., 832.], dtype=float32), array([159., 840.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([745., 568.], dtype=float32), array([894., 552.], dtype=float32), array([908., 713.], dtype=float32), array([757., 725.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([534., 557.], dtype=float32), array([736., 540.], dtype=float32), array([752., 751.], dtype=float32), array([549., 764.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([137., 543.], dtype=float32), array([418., 520.], dtype=float32), array([435., 832.], dtype=float32), array([157., 843.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([749., 568.], dtype=float32), array([899., 555.], dtype=float32), array([911., 714.], dtype=float32), array([760., 731.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([536., 559.], dtype=float32), array([739., 540.], dtype=float32), array([752., 754.], dtype=float32), array([551., 765.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([139., 542.], dtype=float32), array([419., 520.], dtype=float32), array([435., 834.], dtype=float32), array([157., 845.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([756., 570.], dtype=float32), array([907., 558.], dtype=float32), array([918., 716.], dtype=float32), array([768., 728.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([543., 559.], dtype=float32), array([746., 542.], dtype=float32), array([760., 755.], dtype=float32), array([560., 766.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([144., 543.], dtype=float32), array([425., 521.], dtype=float32), array([440., 835.], dtype=float32), array([162., 843.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([756., 568.], dtype=float32), array([906., 557.], dtype=float32), array([919., 713.], dtype=float32), array([767., 727.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([542., 559.], dtype=float32), array([744., 540.], dtype=float32), array([761., 754.], dtype=float32), array([560., 766.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([141., 543.], dtype=float32), array([422., 521.], dtype=float32), array([440., 835.], dtype=float32), array([161., 846.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([754., 568.], dtype=float32), array([906., 554.], dtype=float32), array([919., 713.], dtype=float32), array([767., 727.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([541., 557.], dtype=float32), array([744., 540.], dtype=float32), array([761., 753.], dtype=float32), array([557., 765.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([139., 542.], dtype=float32), array([422., 521.], dtype=float32), array([438., 835.], dtype=float32), array([160., 847.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([757., 568.], dtype=float32), array([910., 555.], dtype=float32), array([923., 715.], dtype=float32), array([769., 727.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([542., 558.], dtype=float32), array([748., 540.], dtype=float32), array([764., 755.], dtype=float32), array([559., 766.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([140., 541.], dtype=float32), array([423., 520.], dtype=float32), array([440., 838.], dtype=float32), array([159., 846.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([753., 569.], dtype=float32), array([905., 555.], dtype=float32), array([919., 717.], dtype=float32), array([767., 728.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([538., 558.], dtype=float32), array([742., 540.], dtype=float32), array([760., 756.], dtype=float32), array([557., 767.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([133., 542.], dtype=float32), array([416., 520.], dtype=float32), array([435., 840.], dtype=float32), array([154., 848.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([750., 570.], dtype=float32), array([903., 559.], dtype=float32), array([917., 719.], dtype=float32), array([762., 730.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([535., 560.], dtype=float32), array([740., 542.], dtype=float32), array([755., 757.], dtype=float32), array([551., 767.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([127., 542.], dtype=float32), array([411., 521.], dtype=float32), array([427., 842.], dtype=float32), array([146., 848.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([746., 569.], dtype=float32), array([899., 559.], dtype=float32), array([912., 717.], dtype=float32), array([759., 730.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([530., 560.], dtype=float32), array([735., 542.], dtype=float32), array([752., 756.], dtype=float32), array([545., 767.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([120., 544.], dtype=float32), array([406., 520.], dtype=float32), array([424., 841.], dtype=float32), array([141., 848.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([739., 568.], dtype=float32), array([895., 555.], dtype=float32), array([908., 716.], dtype=float32), array([753., 728.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([523., 558.], dtype=float32), array([729., 539.], dtype=float32), array([747., 756.], dtype=float32), array([540., 767.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([112., 543.], dtype=float32), array([399., 519.], dtype=float32), array([422., 843.], dtype=float32), array([134., 849.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([736., 570.], dtype=float32), array([892., 557.], dtype=float32), array([906., 718.], dtype=float32), array([750., 731.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([521., 558.], dtype=float32), array([726., 540.], dtype=float32), array([744., 759.], dtype=float32), array([540., 772.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([107., 542.], dtype=float32), array([393., 519.], dtype=float32), array([415., 849.], dtype=float32), array([128., 852.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([736., 572.], dtype=float32), array([891., 559.], dtype=float32), array([905., 718.], dtype=float32), array([748., 731.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([519., 560.], dtype=float32), array([726., 543.], dtype=float32), array([742., 759.], dtype=float32), array([537., 772.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([104., 543.], dtype=float32), array([391., 519.], dtype=float32), array([410., 845.], dtype=float32), array([126., 855.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([734., 570.], dtype=float32), array([888., 558.], dtype=float32), array([903., 717.], dtype=float32), array([746., 730.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([517., 560.], dtype=float32), array([724., 543.], dtype=float32), array([740., 757.], dtype=float32), array([534., 771.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([100., 544.], dtype=float32), array([388., 521.], dtype=float32), array([407., 845.], dtype=float32), array([121., 853.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([737., 572.], dtype=float32), array([894., 557.], dtype=float32), array([907., 720.], dtype=float32), array([749., 734.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([519., 560.], dtype=float32), array([728., 542.], dtype=float32), array([743., 760.], dtype=float32), array([536., 773.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 99., 542.], dtype=float32), array([389., 520.], dtype=float32), array([406., 849.], dtype=float32), array([119., 857.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([739., 573.], dtype=float32), array([896., 560.], dtype=float32), array([909., 723.], dtype=float32), array([750., 735.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([520., 563.], dtype=float32), array([729., 544.], dtype=float32), array([745., 763.], dtype=float32), array([537., 775.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 98., 544.], dtype=float32), array([389., 522.], dtype=float32), array([407., 851.], dtype=float32), array([119., 860.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([740., 575.], dtype=float32), array([898., 562.], dtype=float32), array([911., 723.], dtype=float32), array([752., 736.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([522., 563.], dtype=float32), array([731., 546.], dtype=float32), array([747., 765.], dtype=float32), array([539., 776.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 98., 545.], dtype=float32), array([389., 523.], dtype=float32), array([406., 851.], dtype=float32), array([118., 860.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([741., 576.], dtype=float32), array([899., 561.], dtype=float32), array([913., 725.], dtype=float32), array([753., 737.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([522., 565.], dtype=float32), array([730., 547.], dtype=float32), array([748., 765.], dtype=float32), array([538., 777.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 98., 545.], dtype=float32), array([388., 524.], dtype=float32), array([406., 852.], dtype=float32), array([116., 862.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([740., 574.], dtype=float32), array([898., 561.], dtype=float32), array([911., 726.], dtype=float32), array([752., 738.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([519., 564.], dtype=float32), array([730., 545.], dtype=float32), array([747., 765.], dtype=float32), array([536., 779.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 91., 546.], dtype=float32), array([385., 523.], dtype=float32), array([403., 854.], dtype=float32), array([112., 865.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([738., 577.], dtype=float32), array([897., 562.], dtype=float32), array([912., 726.], dtype=float32), array([752., 740.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([518., 564.], dtype=float32), array([728., 546.], dtype=float32), array([746., 767.], dtype=float32), array([535., 779.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 88., 546.], dtype=float32), array([382., 523.], dtype=float32), array([402., 855.], dtype=float32), array([110., 864.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([734., 577.], dtype=float32), array([891., 563.], dtype=float32), array([907., 728.], dtype=float32), array([747., 740.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([513., 567.], dtype=float32), array([724., 549.], dtype=float32), array([741., 768.], dtype=float32), array([531., 780.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 82., 548.], dtype=float32), array([375., 524.], dtype=float32), array([396., 855.], dtype=float32), array([104., 865.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([727., 578.], dtype=float32), array([886., 562.], dtype=float32), array([901., 727.], dtype=float32), array([740., 740.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([507., 565.], dtype=float32), array([718., 548.], dtype=float32), array([734., 768.], dtype=float32), array([525., 781.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 73., 547.], dtype=float32), array([369., 524.], dtype=float32), array([387., 857.], dtype=float32), array([ 94., 866.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([723., 576.], dtype=float32), array([883., 563.], dtype=float32), array([898., 728.], dtype=float32), array([736., 741.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([501., 564.], dtype=float32), array([712., 546.], dtype=float32), array([730., 769.], dtype=float32), array([519., 782.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 66., 546.], dtype=float32), array([362., 523.], dtype=float32), array([380., 858.], dtype=float32), array([ 86., 866.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([721., 577.], dtype=float32), array([882., 562.], dtype=float32), array([896., 727.], dtype=float32), array([735., 742.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([499., 564.], dtype=float32), array([712., 547.], dtype=float32), array([729., 769.], dtype=float32), array([517., 782.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 64., 544.], dtype=float32), array([359., 522.], dtype=float32), array([378., 859.], dtype=float32), array([ 84., 867.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([718., 576.], dtype=float32), array([879., 564.], dtype=float32), array([892., 731.], dtype=float32), array([732., 743.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([495., 564.], dtype=float32), array([709., 548.], dtype=float32), array([725., 771.], dtype=float32), array([514., 783.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 58., 544.], dtype=float32), array([353., 522.], dtype=float32), array([372., 861.], dtype=float32), array([ 80., 871.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([494., 566.], dtype=float32), array([706., 548.], dtype=float32), array([724., 770.], dtype=float32), array([511., 784.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 54., 546.], dtype=float32), array([351., 523.], dtype=float32), array([371., 864.], dtype=float32), array([ 75., 870.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([718., 579.], dtype=float32), array([879., 568.], dtype=float32), array([892., 729.], dtype=float32), array([731., 742.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([718., 578.], dtype=float32), array([879., 565.], dtype=float32), array([893., 731.], dtype=float32), array([731., 743.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([494., 568.], dtype=float32), array([708., 549.], dtype=float32), array([725., 771.], dtype=float32), array([512., 785.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 52., 545.], dtype=float32), array([353., 524.], dtype=float32), array([367., 864.], dtype=float32), array([ 71., 870.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([723., 577.], dtype=float32), array([884., 563.], dtype=float32), array([898., 728.], dtype=float32), array([734., 743.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([497., 564.], dtype=float32), array([711., 546.], dtype=float32), array([727., 771.], dtype=float32), array([514., 784.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
#  [ 0  0  0]]
# (array([ 53., 544.], dtype=float32), array([354., 521.], dtype=float32), array([369., 863.], dtype=float32), array([ 73., 872.], dtype=float32))
# ________________
# [[   0   20 -180]
#  [  20   20 -180]
#  [  20    0 -180]
#  [   0    0 -180]]
# (array([724., 578.], dtype=float32), array([887., 564.], dtype=float32), array([900., 730.], dtype=float32), array([738., 744.], dtype=float32))
# ________________
# [[  0  20 -90]
#  [ 20  20 -90]
#  [ 20   0 -90]
#  [  0   0 -90]]
# (array([500., 564.], dtype=float32), array([712., 546.], dtype=float32), array([731., 772.], dtype=float32), array([516., 785.], dtype=float32))
# ________________
# [[ 0 20  0]
#  [20 20  0]
#  [20  0  0]
# ...
# (array([238., 556.], dtype=float32), array([544., 536.], dtype=float32), array([564., 851.], dtype=float32), array([259., 865.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([233., 556.], dtype=float32), array([539., 536.], dtype=float32), array([560., 851.], dtype=float32), array([256., 867.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([232., 551.], dtype=float32), array([536., 534.], dtype=float32), array([559., 852.], dtype=float32), array([253., 866.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([229., 552.], dtype=float32), array([535., 533.], dtype=float32), array([555., 851.], dtype=float32), array([249., 865.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([225., 553.], dtype=float32), array([532., 532.], dtype=float32), array([552., 850.], dtype=float32), array([244., 865.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([226., 550.], dtype=float32), array([534., 530.], dtype=float32), array([554., 851.], dtype=float32), array([246., 865.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([226., 549.], dtype=float32), array([535., 530.], dtype=float32), array([555., 851.], dtype=float32), array([245., 865.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([224., 549.], dtype=float32), array([535., 531.], dtype=float32), array([554., 851.], dtype=float32), array([243., 865.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([220., 549.], dtype=float32), array([531., 529.], dtype=float32), array([552., 852.], dtype=float32), array([239., 865.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([217., 548.], dtype=float32), array([529., 529.], dtype=float32), array([550., 853.], dtype=float32), array([237., 866.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([212., 549.], dtype=float32), array([525., 529.], dtype=float32), array([547., 853.], dtype=float32), array([234., 867.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([206., 548.], dtype=float32), array([519., 527.], dtype=float32), array([539., 853.], dtype=float32), array([228., 865.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([196., 547.], dtype=float32), array([511., 525.], dtype=float32), array([533., 852.], dtype=float32), array([219., 866.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([190., 546.], dtype=float32), array([507., 527.], dtype=float32), array([529., 855.], dtype=float32), array([214., 868.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([187., 544.], dtype=float32), array([504., 525.], dtype=float32), array([523., 855.], dtype=float32), array([208., 869.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([180., 544.], dtype=float32), array([498., 520.], dtype=float32), array([524., 853.], dtype=float32), array([205., 867.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([180., 542.], dtype=float32), array([499., 521.], dtype=float32), array([519., 855.], dtype=float32), array([201., 869.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([181., 542.], dtype=float32), array([501., 522.], dtype=float32), array([521., 853.], dtype=float32), array([202., 868.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([178., 545.], dtype=float32), array([500., 521.], dtype=float32), array([522., 855.], dtype=float32), array([201., 871.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([180., 539.], dtype=float32), array([503., 517.], dtype=float32), array([523., 855.], dtype=float32), array([202., 871.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([180., 540.], dtype=float32), array([503., 519.], dtype=float32), array([524., 854.], dtype=float32), array([202., 869.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([173., 544.], dtype=float32), array([498., 520.], dtype=float32), array([520., 855.], dtype=float32), array([198., 872.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([171., 539.], dtype=float32), array([496., 518.], dtype=float32), array([518., 857.], dtype=float32), array([194., 872.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([166., 541.], dtype=float32), array([494., 518.], dtype=float32), array([516., 858.], dtype=float32), array([191., 872.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([158., 543.], dtype=float32), array([486., 518.], dtype=float32), array([509., 858.], dtype=float32), array([184., 873.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([149., 541.], dtype=float32), array([477., 516.], dtype=float32), array([500., 859.], dtype=float32), array([173., 873.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([146., 540.], dtype=float32), array([473., 516.], dtype=float32), array([498., 859.], dtype=float32), array([172., 875.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([142., 542.], dtype=float32), array([470., 516.], dtype=float32), array([494., 860.], dtype=float32), array([165., 877.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([139., 540.], dtype=float32), array([468., 516.], dtype=float32), array([492., 859.], dtype=float32), array([163., 877.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([137., 539.], dtype=float32), array([468., 514.], dtype=float32), array([492., 861.], dtype=float32), array([161., 876.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([131., 539.], dtype=float32), array([462., 513.], dtype=float32), array([486., 863.], dtype=float32), array([156., 878.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([129., 539.], dtype=float32), array([461., 515.], dtype=float32), array([484., 860.], dtype=float32), array([151., 877.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([128., 537.], dtype=float32), array([463., 513.], dtype=float32), array([486., 862.], dtype=float32), array([151., 879.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([130., 537.], dtype=float32), array([466., 514.], dtype=float32), array([488., 863.], dtype=float32), array([152., 881.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([128., 538.], dtype=float32), array([463., 515.], dtype=float32), array([487., 866.], dtype=float32), array([151., 883.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([121., 540.], dtype=float32), array([459., 515.], dtype=float32), array([483., 866.], dtype=float32), array([145., 884.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([119., 539.], dtype=float32), array([457., 515.], dtype=float32), array([482., 870.], dtype=float32), array([143., 885.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([112., 538.], dtype=float32), array([454., 514.], dtype=float32), array([479., 870.], dtype=float32), array([139., 886.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([107., 538.], dtype=float32), array([449., 516.], dtype=float32), array([475., 870.], dtype=float32), array([133., 886.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([100., 540.], dtype=float32), array([441., 516.], dtype=float32), array([466., 872.], dtype=float32), array([125., 889.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 94., 538.], dtype=float32), array([436., 514.], dtype=float32), array([461., 873.], dtype=float32), array([119., 891.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 92., 538.], dtype=float32), array([436., 514.], dtype=float32), array([460., 874.], dtype=float32), array([116., 891.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 90., 539.], dtype=float32), array([434., 515.], dtype=float32), array([458., 876.], dtype=float32), array([114., 892.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 83., 541.], dtype=float32), array([427., 515.], dtype=float32), array([453., 876.], dtype=float32), array([108., 895.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 82., 539.], dtype=float32), array([429., 514.], dtype=float32), array([453., 879.], dtype=float32), array([105., 896.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 80., 539.], dtype=float32), array([428., 514.], dtype=float32), array([452., 881.], dtype=float32), array([103., 897.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 79., 536.], dtype=float32), array([426., 513.], dtype=float32), array([451., 880.], dtype=float32), array([102., 896.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 73., 538.], dtype=float32), array([423., 513.], dtype=float32), array([450., 882.], dtype=float32), array([ 99., 898.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 70., 537.], dtype=float32), array([420., 512.], dtype=float32), array([447., 883.], dtype=float32), array([ 94., 899.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 65., 537.], dtype=float32), array([418., 512.], dtype=float32), array([443., 883.], dtype=float32), array([ 90., 899.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 59., 536.], dtype=float32), array([412., 512.], dtype=float32), array([439., 884.], dtype=float32), array([ 85., 899.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 51., 536.], dtype=float32), array([405., 511.], dtype=float32), array([434., 886.], dtype=float32), array([ 79., 901.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 48., 536.], dtype=float32), array([403., 512.], dtype=float32), array([428., 886.], dtype=float32), array([ 72., 903.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 44., 537.], dtype=float32), array([399., 512.], dtype=float32), array([425., 887.], dtype=float32), array([ 69., 903.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 39., 536.], dtype=float32), array([397., 511.], dtype=float32), array([423., 889.], dtype=float32), array([ 65., 905.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 41., 532.], dtype=float32), array([397., 510.], dtype=float32), array([422., 891.], dtype=float32), array([ 64., 906.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 34., 532.], dtype=float32), array([393., 507.], dtype=float32), array([418., 888.], dtype=float32), array([ 60., 903.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 30., 532.], dtype=float32), array([390., 505.], dtype=float32), array([415., 889.], dtype=float32), array([ 56., 903.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 28., 529.], dtype=float32), array([391., 504.], dtype=float32), array([415., 890.], dtype=float32), array([ 54., 904.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 28., 528.], dtype=float32), array([391., 504.], dtype=float32), array([415., 890.], dtype=float32), array([ 52., 904.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 25., 528.], dtype=float32), array([389., 503.], dtype=float32), array([414., 890.], dtype=float32), array([ 49., 904.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 20., 528.], dtype=float32), array([387., 504.], dtype=float32), array([412., 891.], dtype=float32), array([ 47., 906.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 16., 528.], dtype=float32), array([384., 503.], dtype=float32), array([408., 892.], dtype=float32), array([ 42., 907.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([ 11., 526.], dtype=float32), array([378., 501.], dtype=float32), array([404., 891.], dtype=float32), array([ 35., 904.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([  4., 525.], dtype=float32), array([372., 500.], dtype=float32), array([403., 891.], dtype=float32), array([ 32., 907.], dtype=float32))
# ________________
# [[   0   20 -270]
#  [  20   20 -270]
#  [  20    0 -270]
#  [   0    0 -270]]
# (array([  5., 532.], dtype=float32), array([361., 507.], dtype=float32), array([388., 886.], dtype=float32), array([ 31., 903.], dtype=float32))
# ________________
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [98], in <cell line: 6>()
#       6 while(cap.isOpened()):
#       7   ret, frame = cap.read()
# ----> 8   corners, ids, rejected = cv2.aruco.detectMarkers(frame,arucodict, parameters=arucoParams)
#       9   objp = [0,0,0]
#      10   imgp = [0,0]
#
# error: OpenCV(4.6.0) /io/opencv_contrib/modules/aruco/src/aruco.cpp:1097: error: (-215:Assertion failed) !_image.empty() in function 'detectMarkers'

# %%
print(rot[2,:])
# Out:
# [ 0.         -0.02472273 -0.02004966 -0.02422451 -0.02893904 -0.02561679
#  -0.0257952  -0.02673193 -0.02649129 -0.02744191 -0.03397497 -0.03804122
#  -0.04173076 -0.03934368 -0.03924973 -0.03677639 -0.03004516 -0.02381429
#  -0.01667074 -0.01343117 -0.01592328 -0.0131594  -0.01407772 -0.02400343
#  -0.0307767  -0.02890759 -0.02547972 -0.02818815 -0.02383351 -0.0135169
#  -0.00855362 -0.00717749 -0.00907099 -0.01234031 -0.01705622 -0.02349155
#  -0.02521433 -0.0252298  -0.02392969 -0.01823775 -0.01272996 -0.00770026
#  -0.00485285 -0.00348238 -0.00847016 -0.00451131 -0.01036052 -0.02466631
#  -0.02357511 -0.02204596 -0.02662665 -0.02129028 -0.01846705 -0.01099961
#   0.00049403  0.00318994  0.00337564  0.00532987  0.00031551 -0.0021314
#  -0.00701769 -0.00835279 -0.00498944 -0.00443704  0.00141752  0.01128562
#   0.01669435  0.01914508  0.02362313  0.02467667  0.02315267  0.01731581
#   0.01296633  0.01149912  0.00640905  0.00708936  0.01061433  0.01689424
#   0.02054313  0.02685962  0.03028841  0.03109967  0.03065332  0.02847205
#   0.02503373  0.01832837  0.01243439  0.01347712  0.00373936 -0.02484609
#  -0.02125481 -0.01292154 -0.00748183 -0.01295161 -0.01461881 -0.01405918
#  -0.01518258 -0.02911436 -0.02872025 -0.02785387 -0.03515807 -0.02979633
#  -0.02500434 -0.01535701 -0.00463244 -0.0041867  -0.0023691  -0.00088423
#  -0.00297195 -0.00512042 -0.01094703 -0.01307933 -0.01468596 -0.01731646
#  -0.00997292  0.00032085  0.00261187  0.00299767  0.00699594  0.0100805
#   0.00707751  0.0014057  -0.00309033 -0.00726036 -0.01064263 -0.01273526
#  -0.01238127 -0.0066856   0.00120975  0.00378582  0.00704536  0.01612243
#   0.01125638  0.00910268  0.00673939  0.00294224 -0.00119912 -0.00475132
#  -0.00657404 -0.00658263 -0.00067738  0.00737872  0.00869107  0.0227395
#   0.02221019  0.01719606  0.01949242  0.01598001  0.00524462  0.01062745
#   0.00967699  0.00736133  0.01538232  0.01992728  0.02975343 -0.0456786
#   0.04432436  0.04643291  0.05182786  0.05200271  0.04903895  0.04724736
#   0.04358122  0.04164514  0.04271192  0.04643747  0.0505723   0.05824542
#   0.06678025  0.06972629  0.07626044  0.0754299   0.0770599   0.07377108
#   0.06895983  0.06663917  0.06618415  0.06850055  0.07269064  0.0783521
#   0.08829405  0.09180854  0.10060319  0.10143181  0.09992856  0.10117453
#   0.09796583  0.09251166  0.0930452   0.09171277  0.09242875  0.09678615
#   0.10529554  0.10985971  0.12516998  0.12379467  0.12506642  0.12462976
#   0.12725483 -0.03680021  0.11524473  0.11820983  0.11256143  0.11725639
#   0.12667277  0.1352481  -0.01115689  0.14920891  0.14999486  0.00584934
#   0.00653529  0.0037729   0.00226951  0.00031764 -0.00350011 -0.00328477
#   0.00051913  0.00424062  0.00990986  0.01830567  0.02626107  0.03053545
#   0.03239752  0.03259986  0.03380005  0.02999956  0.02909876  0.02217354
#   0.02571948  0.02875018  0.034268    0.04107092  0.04798601  0.05243083
#   0.05484923  0.05445057  0.05490173  0.05311531  0.04801769  0.04685186
#   0.04547752  0.04504901  0.04890285  0.05485156  0.05891832  0.06656327
#   0.07137315  0.07334199  0.07081036  0.07319652  0.07382929  0.06194337
#   0.05962864  0.04449141  0.02921526 -0.01724598 -0.01090714 -0.0035133
#   0.00597974  0.00542533 -0.01394063  0.01412122  0.01520285  0.01250868
#  -0.01157828  0.00672377  0.00766722  0.01264976  0.01234783 -0.02395674
#   0.02881885  0.03571479  0.04176922  0.04218971 -0.0459804   0.04253558
#  -0.04478135  0.03584401  0.03591745 -0.03583856 -0.03774796  0.03630601
#   0.03703696  0.04003095  0.03159672  0.03324409  0.03166303  0.02287235
#   0.02098762  0.01589538  0.01023749  0.00907781 -0.00647833  0.00953809
#  -0.01505387 -0.02584402 -0.0320255   0.03615689  0.04395124  0.04460144
#   0.04282604 -0.05151095 -0.04282331  0.03248987 -0.03774757  0.03438046
#   0.03021691  0.03633052  0.04021777  0.04700005 -0.06229292  0.06129618
#   0.06851275  0.06748417  0.0649814   0.06291842  0.06086111  0.0569847
#   0.06058176  0.06318181  0.06227413 -0.07898094  0.07946193  0.0856298
#   0.08932658  0.09347925  0.09302391  0.09576157  0.08864361  0.08465629
#   0.08414463  0.08407948  0.08686613  0.08892826  0.0974606   0.10255256
#   0.10712019  0.11361081  0.11420348  0.11479713  0.11663319  0.11190314
#   0.11120064  0.11231396  0.11160013  0.11544992 -0.12880237  0.12565469
#   0.13487075  0.14000389  0.14380047  0.13969824  0.14273984  0.14275801
#   0.13323979  0.13143735  0.13258937  0.12748599  0.13093337  0.13584583
#   0.14154805  0.15348666  0.16176294  0.16170092  0.17121853  0.17184182
#   0.16616821  0.17265333  0.16245323  0.16317311  0.16945841  0.16885998
#   0.17226868  0.18297332  0.18469845  0.19096631  0.19466621  0.19128228
#   0.19329681  0.19435607  0.18676426  0.18407321  0.18305176  0.18454792
#   0.18470525  0.18948976  0.19348339  0.20192931  0.20468484  0.20886682
#   0.20624027  0.20492418  0.20701457  0.20300192  0.19910112  0.1968477
#   0.19549085  0.19964728  0.20635352  0.21218853  0.21849286  0.22189829
#   0.22548596  0.2256396   0.22374886  0.21962506  0.21337521  0.21164474
#   0.20616733  0.20730699  0.20897934  0.19796959  0.03708987  0.05808188
#   0.03336817  0.03310606  0.0571644   0.02930971 -0.04071671 -0.04433602
#   0.04009513 -0.04692905  0.02487966  0.06240732  0.0243924   0.02977907
#   0.05410329  0.01677359 -0.034767    0.03972696  0.06116612  0.02603377
#   0.03667676 -0.03441211  0.03958812  0.03612207  0.02978441  0.05123302
#   0.04989876 -0.02869683  0.04901896  0.05214471  0.054194    0.0374996
#   0.03325407  0.05122896  0.05788982  0.04480573  0.04490313  0.04763629
#   0.0529889  -0.0417888   0.05231488  0.03389988  0.05051772  0.04959322
#  -0.06275219  0.0357429   0.02837982  0.04983796  0.06005516 -0.05817154
#   0.04061078 -0.05212954  0.05323086  0.06020494 -0.03504082  0.04121787
#   0.04614114  0.05793204  0.05093566 -0.03305169  0.05079275  0.05012065
#   0.04240592  0.04199685  0.05772271  0.04590323  0.04962183  0.05989445
#   0.0708322   0.04766919  0.06162873  0.06775252 -0.05163061  0.05395691
#   0.06119454  0.05648624 -0.0619201   0.05715923  0.07474445  0.06599916
#   0.05140785  0.06439104  0.05742993  0.0634926  -0.08729705  0.07299156
#  -0.05946892  0.07609716 -0.06870632  0.0546879  -0.06299717 -0.06824827
#   0.06500267  0.07642364  0.06810449  0.07025761  0.07769234  0.07662113
#   0.08146477  0.06260528  0.06296962  0.08349324  0.06668811  0.05845726
#   0.07700291  0.06762272  0.06504247  0.07264668  0.08261468 -0.07253734
#   0.06926009  0.07466883  0.08956508 -0.05840942  0.06564506  0.06221876
#  -0.07504977  0.05977961 -0.07654187  0.06989838  0.05901337  0.06878731
#   0.07775891  0.07122563  0.07479315 -0.07233673 -0.07447947 -0.07780845
#  -0.08352221 -0.07971744 -0.08256993  0.07463743 -0.07881028  0.08556655
#  -0.07665994 -0.07922118  0.08030657 -0.09860424  0.08846163  0.09231414
#   0.09185799  0.08863537  0.08530226  0.08154511  0.08278767 -0.08166552
#  -0.08423369 -0.08850517]

# %%
a,b = b,a

# %%
a = [0,0,0,0]
b = np.random.rand(4,4)

# %%
np.vstack((a,b))
# Out:
# array([[0.        , 0.        , 0.        , 0.        ],
#        [0.31487656, 0.58577576, 0.93284665, 0.71314846],
#        [0.81640548, 0.06376371, 0.22980325, 0.44702081],
#        [0.95322497, 0.25340214, 0.74738163, 0.09421588],
#        [0.08896607, 0.60846572, 0.61127917, 0.43693554]])
